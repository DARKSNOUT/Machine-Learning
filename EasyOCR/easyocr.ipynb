# %%
import easyocr as ocr
import numpy as np
import  pandas as pd

# %%
reader=ocr.Reader(["en"])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
result1=reader.readtext('plate2.png')
results
# Out:
# [([[174, 313], [271, 313], [271, 378], [174, 378]],
#   'INDI',
#   0.7023870348930359),
#  ([[238, 210], [934, 210], [934, 427], [238, 427]],
#   'MHO 1AE8Q1Z]',
#   0.14164261188683835)]

# %%
result2=reader.readtext('plate.png')
result2
# Out:
# [([[80, 116], [158, 116], [158, 148], [80, 148]], 'MH 03', 0.3616410389231552),
#  ([[77, 145], [93, 145], [93, 167], [77, 167]], 'P', 0.6015405916954855),
#  ([[95, 139], [167, 139], [167, 175], [95, 175]], '2521', 0.9999662637710571)]

# %%
result3=reader.readtext('plate3.png')
result3
# Out:
# [([[79, 75], [233, 75], [233, 111], [79, 111]],
#   '21 BH 2345 AA',
#   0.7482547050296401)]

# %%
frame=pd.DataFrame(result)
frame
# Out:
#                                                     0  \
# 0   ([[344, 32], [414, 32], [414, 58], [344, 58]],...
# 1   ([[637, 221], [852, 221], [852, 257], [637, 25...
# 2   ([[866, 220], [1046, 220], [1046, 250], [866, ...
# 3   ([[1070, 214], [1441, 214], [1441, 257], [1070...
# 4   ([[372, 308], [524, 308], [524, 338], [372, 33...
# ..                                                ...
# 63  ([[423, 1485], [453, 1485], [453, 1502], [423,...
# 64  ([[461, 1485], [521, 1485], [521, 1502], [461,...
# 65  ([[643, 1487], [789, 1487], [789, 1502], [643,...
# 66  ([[817, 1485], [991, 1485], [991, 1502], [817,...
# 67  ([[995, 1491], [1045, 1491], [1045, 1502], [99...
#
#                                                     1  \
# 0   ([[373, 133], [477, 133], [477, 169], [373, 16...
# 1                                                None
# 2                                                None
# 3                                                None
# ...

# %%
print(results)
# Out:
# [([[344, 32], [414, 32], [414, 58], [344, 58]], 'micro', 0.9999655603683119), ([[373, 133], [477, 133], [477, 169], [373, 169]], 'By date', 0.969510448653269), ([[595, 135], [721, 135], [721, 171], [595, 171]], 'By group', 0.9999859229115561), ([[372, 220], [524, 220], [524, 250], [372, 250]], 'Oct 29, 2023', 0.7972336446415859), ([[637, 221], [852, 221], [852, 257], [637, 257]], 'Exam Registration', 0.7988949865148119), ([[866, 220], [1046, 220], [1046, 250], [866, 250]], 'Schedule Exam', 0.9913975341096201), ([[1070, 214], [1441, 214], [1441, 257], [1070, 257]], 'examregistration microsoftcom', 0.9976320858317146), ([[372, 308], [524, 308], [524, 338], [372, 338]], 'Oct 29, 2023', 0.7972336446415859), ([[637, 307], [1239, 307], [1239, 345], [637, 345]], 'Exam PL-100: Microsoft Power Platform App Maker', 0.7364438023987206), ([[1252, 308], [1412, 308], [1412, 340], [1252, 340]], 'Certifications', 0.9998341768470992), ([[1425, 307], [1614, 307], [1614, 339], [1425, 339]], 'Microsoft 
# ...

# %%
results.shape()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\harsh\OneDrive\Desktop\ML\easyOCR\easyocr.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/harsh/OneDrive/Desktop/ML/easyOCR/easyocr.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> results.shape()
#
# AttributeError: 'list' object has no attribute 'shape'
